# %%
# -*- coding: UTF-8 -*-

import string 
import keyword
import sys
import requests
import math
from bs4 import BeautifulSoup
#import easygui

#easygui.msgbox("Welcome to Gossiping Parser")

def isNum(value):
    try:
        value + 1
    except TypeError:
        return False
    else:
        return True

def isNum2(value):
    try:
        x = int(value)
    except TypeError:
        return False
    except ValueError:
        return False
    except Exception:
        return False
    else:
        return True

n = 999
def inputWhich():
	x = input(">>> Which one do you want to see? (1~{}) or show post list (list), to exit (exit), to re-load list (refresh) : ".format(n))
	return x
	
ptt_domain = "https://www.ptt.cc"
payload = {
'from':'/bbs/Gossiping/index.html',
'yes':'yes'
}

rs = requests.session()
res = rs.post(ptt_domain + '/ask/over18', verify=False, data=payload)

post_list = []
連結列表 = []
清單列表 = []

def freshList():
	res = rs.get(ptt_domain + '/bbs/Gossiping/index.html', verify=False)
	print("網頁編碼 : ", res.encoding)

	# Use BeautifulSoup
	soup = BeautifulSoup(res.text)

	for entry in soup.select('.r-ent'):
		href = ""
		for a in entry.find_all('a', href=True):
			連結列表.append(a['href'])
			href = a['href']

		post_content = entry.select('.date')[0].text + " " + entry.select('.author')[0].text + " " + entry.select('.title')[0].text
		post_list.append(post_content)
		清單列表.append({'href':href, 'content':post_content})
	
def showList():
	i = 1
	for list_content in 清單列表:
		print(i, ' : ', list_content['content'].encode(sys.stdin.encoding, "replace").decode(sys.stdin.encoding))
		i = i+1
		
	print("程式預設編碼 : ",sys.getdefaultencoding(), ", cmd預設編碼 : ",sys.stdin.encoding)

freshList()
showList()
	
input_test = ""
check_word = "exit"
while input_test != check_word:
	n = len(清單列表)
	input_test = inputWhich()
	if input_test.isdigit():
		index = int(input_test)-1
		if index < len(清單列表) and -1 < index:
			清單上的內容 = 清單列表[index]
			if "" != 清單上的內容['href']:
				res = rs.get(ptt_domain + 清單上的內容['href'], verify=False)
				soup = BeautifulSoup(res.text)
				text = soup.find('div', id='main-content')
				text = '\n'.join(text.findAll(text=True)).strip();
				print(text.encode(sys.stdin.encoding, "replace").decode(sys.stdin.encoding))
		else:
			print("error : ", index , len(連結列表))
		
	if input_test == "list":
		showList()
		
	if input_test == "refresh":
		post_list = []
		連結列表 = []
		freshList()
		showList()
# Out:
# C:\Users\user1\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# C:\Users\user1\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# C:\Users\user1\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# 網頁編碼 :  utf-8
# 1  :  11/30 str8g
# [新聞] 被指台獨份子 黃安暴怒發文飆粗口
#
# 2  :  11/30 homechen1990
# [問卦] 有沒有安納金是豬隊友的八卦
#
# 3  :  11/30 Cassander
# [新聞] 歷經30年　布吉納法索首度選總統
#
# 4  :  11/30 swda200791
# Re: [問卦] 有沒有死T店員的八卦?
#
# 5  :  11/30 Xmmmmmmmmmmm
# Re: [ＦＢ] 林致宇:柯文哲根本是國民黨側翼的側翼
#
# 6  :  11/30 hsiyafel
# Re: [問卦] 某牌家電維修公司說要告我
#
# 7  :  11/30 NotFunny
# [問卦] 有沒有便利商店打工超累人的八卦
#
# 8  :  11/30 uke3458
# [問卦] 有沒有涼山特勤隊的掛?
#
# 9  :  11/30 ReDmango
# Re: [ＦＢ] 林致宇:柯文哲根本是國民黨側翼的側翼
#
# 10  :  11/30 rutw
# [新聞] 誤認 蕭萬長 為 泰國總理 白宮更正
#
# 11  :  11/30 jeanvanjohn
# Re: [ＦＢ] 林致宇:柯文哲根本是國民黨側翼的側翼
#
# 12  :  11/30 bluepong
# [問卦] 網購396萬禮券遭跳票　賣家嗆：不怕被告
#
# 13  :  11/30 NINTENDO
# Re: [公告] 十一月份置底閒聊區
#
# 14  :  11/30 tom77588
# [新聞] 回顧連勝文這支廣告 網友讚：有一件事他
#
# 15  :  11/30 SPFH120
# Re: [新聞]     潤泰賠2億幫住戶重蓋創史上首例
#
# 16  :  11/30 sean12345678
# Re: [問卦] 西點軍校生的素質
#
# 17  :   6/16 seabox
# [公告] 八卦板板規(2015.06.16)
#
# 18  :  11/23 seabox
# [公告] 數條板規修改草案於GossipPicket討論
#
# 19  :  11/25 LinIsGod
# [協尋] 11/24 早上九點 國一南崁交流道死亡車禍
#
# 20  :  11/27 CannyGin
# 徵求_梓官死亡車禍  目擊或紀錄
#
# 21  :  10/31 meowmeowgo
# [公告] 十一月份置底閒聊區
#
# 程式預設編碼 :  utf-8 , cmd預設編碼 :  cp950
# >>> Which one do you want to see? (1~21) or show post list (list), to exit (exit), to re-load list (refresh) : 16
# C:\Users\user1\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:768: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# 作者
# sean12345678 (男人)
# 看板
# Gossiping
# 標題
# Re: [問卦] 西點軍校生的素質
# 時間
# Mon Nov 30 14:33:21 2015
#
#
# ※ 引述《dermer (der毛)》之銘言：
#
# : 小弟在GE工作，公司裡有個leadership program叫JOLP (junior officer leadership pr
#
# : ogram), 就專收西點軍校畢業的退伍軍官（而且只收有機會升general那個track的軍官）
#
# : 。
#
# : 公司對他們非常禮遇，八大事業體的工作隨便他們挑，想做什麼部門的工作也都隨他們。
#
# 我國軍官有黨證的話, 更多禮遇.
# 八大事業體? 我國黨營事業那麼多, 隨便挑吧.
#
#
# : 他們工作能力真的超強，身體素質超好怎麼加班都不怕，做事風格迅速準確，判斷局勢也
#
# 還要加班? 我國的國營事業, 幾乎不用加班耶
#
# : 很有大局觀，看得出來西點畢業的真的是菁英中的菁英。
#
# 他們有大局觀? 我國的 可以操縱大局, 想怎麼做就怎麼做. 美國輸我國官校超多.
#
# : 八卦是他們每天幾乎都不用睡覺，天天還會固定魔鬼訓練健身一個小時。我常常半夜三點
#
# 睡眠不足是美容的最大敵人, 西方人容易老 是有道理的.
#
# : 收到其中一個JOLP畢業的同事的郵件，然後第二天早上七點進辦公室的時候對方已經晨跑
#
# 你為什麼那麼奴? 半夜還要查郵件? 不是在美國工作嗎? 七點進辦公室?
# 我國有的中午進辦公室就行了耶. 上班時間 還可以去辦自己的事.
#
# : 完在自己的座位上待命了。
#
# : 我常常聽他們講在伊拉克作戰時候的一些經驗和戰績，深深的感覺到美國軍官這麼優秀真
#
# 我國愛好和平, 不打仗, 不侵略其他國家.
#
# : 的不是在蓋的，畢竟每天面對的都是生與死的decision，沒有超人般的精神力和領導力真
#
# : 的是沒辦法勝任這樣的工作。
#
# 在GE工作 有生命危險嗎? 趕快離職啦. 加入國軍.
# 熬出頭 你可以得到比美國退伍軍官好很多的工作.
#
# --
#
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.44.182.179
#
# ※ 文章網址:
# https://www.ptt.cc/bbs/Gossiping/M.1448865204.A.D95.html
